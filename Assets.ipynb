# %% [markdown]
# <a href="https://colab.research.google.com/github/navigargi/Google-Colab/blob/main/Assets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

def calculate_monthly_expenses(home_value, option):
    """Calculates monthly expenses based on home value or rent."""
    if option == 1:  # Homeownership
        utilities = 0.01 * home_value / 12
        maintenance = 0.01 * home_value / 12
        property_tax = 0.014 * home_value / 12
        insurance = 0.004 * home_value / 12
        return utilities + maintenance + property_tax + insurance
    else:  # Renting
        return 0.1 * home_value

def calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years):
    """Calculates the monthly mortgage payment."""
    monthly_interest_rate = annual_interest_rate / 12 / 100
    loan_term_months = loan_term_years * 12
    return (loan_amount * monthly_interest_rate * (1 + monthly_interest_rate) ** loan_term_months) / (
        (1 + monthly_interest_rate) ** loan_term_months - 1)

def calculate_savings(income, expenses, credit_card, insurance, pension, misc, mortgage):
    """Calculates monthly savings based on income and expenses."""
    return income - (expenses + credit_card + insurance + pension + misc + mortgage)

def calculate_investment_return(equities, market_return, tax_rate):
    """Calculates the monthly investment return after taxes."""
    return (equities * market_return) * (1 - tax_rate)

def simulate_financial_life(annual_active_income, current_equities, cash, credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value,  # Added home_value as argument
                             loan_amount, annual_interest_rate, loan_term_years, savings_percentage, cash_percentage,
                             equity_percentage, retirement_year, monthly_prepayment):
    """Simulates financial life based on user inputs and calculates financial metrics."""

    data = {}
    data["annual_active_income"] = annual_active_income
    data["current_equities"] = current_equities
    data["cash"] = cash
    data["credit_card"] = credit_card
    data["insurance"] = insurance
    data["pension"] = pension
    data["misc"] = misc
    data["tax_on_active_income"] = 0.2  # Replace with actual tax rate
    data["avg_ann_income_raise"] = 0.02  # Replace with actual average annual income raise
    data["avg_ann_inflation"] = 0.03  # Replace with actual average annual inflation
    data["tax_on_investment_gains"] = 0.15  # Replace with actual tax rate
    data["avg_monthly_market_returns"] = 0.007  # Replace with actual average monthly market returns
    data["avg_monthly_market_volatility"] = 0.02  # Replace with actual average monthly market volatility
    data["retirement_year"] = retirement_year
    data["maturity"] = loan_term_years
    data["savings_percentage"] = savings_percentage / 100

    df = pd.DataFrame(columns=["Month", "Assets", "Outflows", "Inflows", "Income", "Investment Return",
                               "Rent", "CreditCard", "Insurance", "Pension", "Misc", "Mortgage", "Savings", "Equity", "Cash"])

    monthly_expenses = calculate_monthly_expenses(home_value, rent_or_mortgage) # Now home_value is available
    monthly_mortgage_payment = calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years)

    assets = current_equities + cash
    for month in range(1, 12 * retirement_year + 1):
        income = data["annual_active_income"] / 12

# %%
import pandas as pd
import numpy as np

def calculate_monthly_expenses(home_value, option):
    """Calculates monthly expenses based on home value or rent."""
    if option == 1:  # Homeownership
        utilities = 0.01 * home_value / 12
        maintenance = 0.01 * home_value / 12
        property_tax = 0.014 * home_value / 12
        insurance = 0.004 * home_value / 12
        return utilities + maintenance + property_tax + insurance
    else:  # Renting
        return 0.1 * home_value

def calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years):
    """Calculates the monthly mortgage payment."""
    monthly_interest_rate = annual_interest_rate / 12 / 100
    loan_term_months = loan_term_years * 12
    return (loan_amount * monthly_interest_rate * (1 + monthly_interest_rate) ** loan_term_months) / (
        (1 + monthly_interest_rate) ** loan_term_months - 1)

def calculate_savings(income, expenses, credit_card, insurance, pension, misc, mortgage):
    """Calculates monthly savings based on income and expenses."""
    return income - (expenses + credit_card + insurance + pension + misc + mortgage)

def calculate_investment_return(equities, market_return, tax_rate):
    """Calculates the monthly investment return after taxes."""
    return (equities * market_return) * (1 - tax_rate)

def simulate_financial_life(annual_active_income, current_equities, cash, credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value,  # Added home_value as argument
                             loan_amount, annual_interest_rate, loan_term_years, savings_percentage, cash_percentage,
                             equity_percentage, retirement_year, monthly_prepayment):
    """Simulates financial life based on user inputs and calculates financial metrics."""

    data = {}
    data["annual_active_income"] = annual_active_income
    data["current_equities"] = current_equities
    data["cash"] = cash
    data["credit_card"] = credit_card
    data["insurance"] = insurance
    data["pension"] = pension
    data["misc"] = misc
    data["tax_on_active_income"] = 0.2  # Replace with actual tax rate
    data["avg_ann_income_raise"] = 0.02  # Replace with actual average annual income raise
    data["avg_ann_inflation"] = 0.03  # Replace with actual average annual inflation
    data["tax_on_investment_gains"] = 0.15  # Replace with actual tax rate
    data["avg_monthly_market_returns"] = 0.007  # Replace with actual average monthly market returns
    data["avg_monthly_market_volatility"] = 0.02  # Replace with actual average monthly market volatility
    data["retirement_year"] = retirement_year
    data["maturity"] = loan_term_years
    data["savings_percentage"] = savings_percentage / 100

    df = pd.DataFrame(columns=["Month", "Assets", "Outflows", "Inflows", "Income", "Investment Return",
                               "Rent", "CreditCard", "Insurance", "Pension", "Misc", "Mortgage", "Savings", "Equity", "Cash"])

    monthly_expenses = calculate_monthly_expenses(home_value, rent_or_mortgage) # Now home_value is available
    monthly_mortgage_payment = calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years)

    assets = current_equities + cash
    for month in range(1, 12 * retirement_year + 1):
        income = data["annual_active_income"] / 12

        investment_return = calculate_investment_return(current_equities, data["avg_monthly_market_returns"],
                                                        data["tax_on_investment_gains"])

        if rent_or_mortgage == 1:
          rent = 0
          mortgage = monthly_mortgage_payment
        else:
          rent = monthly_expenses
          mortgage = 0

        savings = calculate_savings(income, monthly_expenses, credit_card, insurance, pension, misc, mortgage)

        outflows = monthly_expenses + credit_card + insurance + pension + misc + mortgage
        inflows = income + investment_return

        assets = assets + inflows - outflows
        current_equities = current_equities + equity_percentage/100 * savings + investment_return
        cash = cash + cash_percentage/100 * savings

        new_row = pd.DataFrame({"Month": [month], "Assets": [assets], "Outflows": [outflows], "Inflows": [inflows],
                                "Income": [income], "Investment Return": [investment_return], "Rent": [rent],
                                "CreditCard": [credit_card], "Insurance": [insurance], "Pension": [pension],
                                "Misc": [misc], "Mortgage": [mortgage], "Savings": [savings],
                                "Equity": [current_equities], "Cash": [cash]})
        df = pd.concat([df, new_row], ignore_index=True)

        # Apply annual income raise and inflation adjustments
        data["annual_active_income"] *= (1 + data["avg_ann_income_raise"])
        monthly_expenses *= (1 + data["avg_ann_inflation"])
        credit_card *= (1 + data["avg_ann_inflation"])
        insurance *= (1 + data["avg_ann_inflation"])
        pension *= (1 + data["avg_ann_inflation"])
        misc *= (1 + data["avg_ann_inflation"])

    return df

# Example usage
df = simulate_financial_life(annual_active_income=60000, current_equities=100000, cash=20000,
                             credit_card=500, insurance=200, pension=300, misc=400,
                             rent_or_mortgage=1, home_value=500000, loan_amount=400000,
                             annual_interest_rate=3, loan_term_years=30, savings_percentage=20,
                             cash_percentage=20, equity_percentage=80, retirement_year=30, monthly_prepayment=0)

print(df)
# Out:
# /tmp/ipython-input-2-2768570314.py:88: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)
#     Month        Assets      Outflows       Inflows        Income  \
# 0       1  1.209253e+05  4.669749e+03  5.595000e+03  5.000000e+03
# 1       2  1.218661e+05  4.759249e+03  5.700112e+03  5.100000e+03
# 2       3  1.228220e+05  4.851434e+03  5.807305e+03  5.202000e+03
# 3       4  1.237922e+05  4.946385e+03  5.916615e+03  5.306040e+03
# 4       5  1.247761e+05  5.044184e+03  6.028081e+03  5.412161e+03
# ..    ...           ...           ...           ...           ...
# 355   356 -4.043229e+09  1.076275e+08 -1.375147e+07  5.649773e+06
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def calculate_monthly_expenses(home_value, option):
    """Calculates monthly expenses based on home value or rent."""
    if option == 1:  # Homeownership
        utilities = 0.01 * home_value / 12
        maintenance = 0.01 * home_value / 12
        property_tax = 0.014 * home_value / 12
        insurance = 0.004 * home_value / 12
        return utilities + maintenance + property_tax + insurance
    else:  # Renting
        return 0.1 * home_value

def calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years):
    """Calculates the monthly mortgage payment."""
    monthly_interest_rate = annual_interest_rate / 12 / 100
    loan_term_months = loan_term_years * 12
    return (loan_amount * monthly_interest_rate * (1 + monthly_interest_rate) ** loan_term_months) / (
        (1 + monthly_interest_rate) ** loan_term_months - 1)

def calculate_savings(income, expenses, credit_card, insurance, pension, misc, mortgage):
    """Calculates monthly savings based on income and expenses."""
    return income - (expenses + credit_card + insurance + pension + misc + mortgage)

def calculate_investment_return(equities, market_return, tax_rate):
    """Calculates the monthly investment return after taxes."""
    return (equities * market_return) * (1 - tax_rate)

def simulate_financial_life(annual_active_income, current_equities, cash, credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value,  # Added home_value as argument
                             loan_amount, annual_interest_rate, loan_term_years, savings_percentage, cash_percentage,
                             equity_percentage, retirement_year, monthly_prepayment):
    """Simulates financial life based on user inputs and calculates financial metrics."""

    data = {}
    data["annual_active_income"] = annual_active_income
    data["current_equities"] = current_equities
    data["cash"] = cash
    data["credit_card"] = credit_card
    data["insurance"] = insurance
    data["pension"] = pension
    data["misc"] = misc
    data["tax_on_active_income"] = 0.2  # Replace with actual tax rate
    data["avg_ann_income_raise"] = 0.02  # Replace with actual average annual income raise
    data["avg_ann_inflation"] = 0.03  # Replace with actual average annual inflation
    data["tax_on_investment_gains"] = 0.15  # Replace with actual tax rate
    data["avg_monthly_market_returns"] = 0.007  # Replace with actual average monthly market returns
    data["avg_monthly_market_volatility"] = 0.02  # Replace with actual average monthly market volatility
    data["retirement_year"] = retirement_year
    data["maturity"] = loan_term_years
    data["savings_percentage"] = savings_percentage / 100

    df = pd.DataFrame(columns=["Month", "Assets", "Outflows", "Inflows", "Income", "Investment Return",
                               "Rent", "CreditCard", "Insurance", "Pension", "Misc", "Mortgage", "Savings", "Equity", "Cash"])

    monthly_expenses = calculate_monthly_expenses(home_value, rent_or_mortgage) # Now home_value is available
    monthly_mortgage_payment = calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years)

    assets = current_equities + cash
    for month in range(1, 12 * retirement_year + 1):
        income = data["annual_active_income"] / 12

        investment_return = calculate_investment_return(current_equities, data["avg_monthly_market_returns"],
                                                        data["tax_on_investment_gains"])

        if rent_or_mortgage == 1:
          rent = 0
          mortgage = monthly_mortgage_payment
        else:
          rent = monthly_expenses
          mortgage = 0

        savings = calculate_savings(income, monthly_expenses, credit_card, insurance, pension, misc, mortgage)

        outflows = monthly_expenses + credit_card + insurance + pension + misc + mortgage
        inflows = income + investment_return

        assets = assets + inflows - outflows
        current_equities = current_equities + equity_percentage/100 * savings + investment_return
        cash = cash + cash_percentage/100 * savings

        new_row = pd.DataFrame({"Month": [month], "Assets": [assets], "Outflows": [outflows], "Inflows": [inflows],
                                "Income": [income], "Investment Return": [investment_return], "Rent": [rent],
                                "CreditCard": [credit_card], "Insurance": [insurance], "Pension": [pension],
                                "Misc": [misc], "Mortgage": [mortgage], "Savings": [savings],
                                "Equity": [current_equities], "Cash": [cash]})
        df = pd.concat([df, new_row], ignore_index=True)

        # Apply annual income raise and inflation adjustments
        data["annual_active_income"] *= (1 + data["avg_ann_income_raise"])
        monthly_expenses *= (1 + data["avg_ann_inflation"])
        credit_card *= (1 + data["avg_ann_inflation"])
        insurance *= (1 + data["avg_ann_inflation"])
        pension *= (1 + data["avg_ann_inflation"])
        misc *= (1 + data["avg_ann_inflation"])

    return df

# Example usage
df = simulate_financial_life(annual_active_income=60000, current_equities=100000, cash=20000,
                             credit_card=500, insurance=200, pension=300, misc=400,
                             rent_or_mortgage=1, home_value=500000, loan_amount=400000,
                             annual_interest_rate=3, loan_term_years=30, savings_percentage=20,
                             cash_percentage=20, equity_percentage=80, retirement_year=30, monthly_prepayment=0)

# Create the graph
plt.plot(df['Month'], df['Assets'])
plt.xlabel('Month')
plt.ylabel('Total Assets')
plt.title('Total Assets vs Month')
plt.show()
# Out:
# <ipython-input-4-14fd91394987>:91: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)

# %%
# prompt: can you ask the user for all the fields of information in the above code

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def calculate_monthly_expenses(home_value, option):
    """Calculates monthly expenses based on home value or rent."""
    if option == 1:  # Homeownership
        utilities = 0.01 * home_value / 12
        maintenance = 0.01 * home_value / 12
        property_tax = 0.014 * home_value / 12
        insurance = 0.004 * home_value / 12
        return utilities + maintenance + property_tax + insurance
    else:  # Renting
        return 0.1 * home_value

def calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years):
    """Calculates the monthly mortgage payment."""
    monthly_interest_rate = annual_interest_rate / 12 / 100
    loan_term_months = loan_term_years * 12
    return (loan_amount * monthly_interest_rate * (1 + monthly_interest_rate) ** loan_term_months) / (
        (1 + monthly_interest_rate) ** loan_term_months - 1)

def calculate_savings(income, expenses, credit_card, insurance, pension, misc, mortgage):
    """Calculates monthly savings based on income and expenses."""
    return income - (expenses + credit_card + insurance + pension + misc + mortgage)

def calculate_investment_return(equities, market_return, tax_rate):
    """Calculates the monthly investment return after taxes."""
    return (equities * market_return) * (1 - tax_rate)

def simulate_financial_life(annual_active_income, current_equities, cash, credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value,  # Added home_value as argument
                             loan_amount, annual_interest_rate, loan_term_years, savings_percentage, cash_percentage,
                             equity_percentage, retirement_year, monthly_prepayment):
    """Simulates financial life based on user inputs and calculates financial metrics."""

    data = {}
    data["annual_active_income"] = annual_active_income
    data["current_equities"] = current_equities
    data["cash"] = cash
    data["credit_card"] = credit_card
    data["insurance"] = insurance
    data["pension"] = pension
    data["misc"] = misc
    data["tax_on_active_income"] = 0.2  # Replace with actual tax rate
    data["avg_ann_income_raise"] = 0.02  # Replace with actual average annual income raise
    data["avg_ann_inflation"] = 0.03  # Replace with actual average annual inflation
    data["tax_on_investment_gains"] = 0.15  # Replace with actual tax rate
    data["avg_monthly_market_returns"] = 0.007  # Replace with actual average monthly market returns
    data["avg_monthly_market_volatility"] = 0.02  # Replace with actual average monthly market volatility
    data["retirement_year"] = retirement_year
    data["maturity"] = loan_term_years
    data["savings_percentage"] = savings_percentage / 100

    df = pd.DataFrame(columns=["Month", "Assets", "Outflows", "Inflows", "Income", "Investment Return",
                               "Rent", "CreditCard", "Insurance", "Pension", "Misc", "Mortgage", "Savings", "Equity", "Cash"])

    monthly_expenses = calculate_monthly_expenses(home_value, rent_or_mortgage) # Now home_value is available
    monthly_mortgage_payment = calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years)

    assets = current_equities + cash
    for month in range(1, 12 * retirement_year + 1):
        income = data["annual_active_income"] / 12

        investment_return = calculate_investment_return(current_equities, data["avg_monthly_market_returns"],
                                                        data["tax_on_investment_gains"])

        if rent_or_mortgage == 1:
          rent = 0
          mortgage = monthly_mortgage_payment
        else:
          rent = monthly_expenses
          mortgage = 0

        savings = calculate_savings(income, monthly_expenses, credit_card, insurance, pension, misc, mortgage)

        outflows = monthly_expenses + credit_card + insurance + pension + misc + mortgage
        inflows = income + investment_return

        assets = assets + inflows - outflows
        current_equities = current_equities + equity_percentage/100 * savings + investment_return
        cash = cash + cash_percentage/100 * savings

        new_row = pd.DataFrame({"Month": [month], "Assets": [assets], "Outflows": [outflows], "Inflows": [inflows],
                                "Income": [income], "Investment Return": [investment_return], "Rent": [rent],
                                "CreditCard": [credit_card], "Insurance": [insurance], "Pension": [pension],
                                "Misc": [misc], "Mortgage": [mortgage], "Savings": [savings],
                                "Equity": [current_equities], "Cash": [cash]})
        df = pd.concat([df, new_row], ignore_index=True)

        # Apply annual income raise and inflation adjustments
        data["annual_active_income"] *= (1 + data["avg_ann_income_raise"])
        monthly_expenses *= (1 + data["avg_ann_inflation"])
        credit_card *= (1 + data["avg_ann_inflation"])
        insurance *= (1 + data["avg_ann_inflation"])
        pension *= (1 + data["avg_ann_inflation"])
        misc *= (1 + data["avg_ann_inflation"])

    return df


# Get user inputs
annual_active_income = float(input("Enter your annual active income: "))
current_equities = float(input("Enter your current equities: "))
cash = float(input("Enter your current cash: "))
credit_card = float(input("Enter your monthly credit card expenses: "))
insurance = float(input("Enter your monthly insurance expenses: "))
pension = float(input("Enter your monthly pension contributions: "))
misc = float(input("Enter your monthly miscellaneous expenses: "))
rent_or_mortgage = int(input("Enter 1 if you have a mortgage, 2 if you rent: "))
home_value = float(input("Enter your home value or monthly rent: "))
loan_amount = float(input("Enter your loan amount (0 if renting): "))
annual_interest_rate = float(input("Enter your annual interest rate (0 if renting): "))
loan_term_years = int(input("Enter your loan term in years (0 if renting): "))
savings_percentage = float(input("Enter your savings percentage: "))
cash_percentage = float(input("Enter the percentage of savings to be kept in cash: "))
equity_percentage = float(input("Enter the percentage of savings to be invested in equities: "))
retirement_year = int(input("Enter your desired retirement year: "))
monthly_prepayment = float(input("Enter your monthly mortgage prepayment amount (0 if no prepayment): "))

# Example usage with user inputs
df = simulate_financial_life(annual_active_income, current_equities, cash,
                             credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value, loan_amount,
                             annual_interest_rate, loan_term_years, savings_percentage,
                             cash_percentage, equity_percentage, retirement_year, monthly_prepayment)

print(df)

# Create the graph
plt.plot(df['Month'], df['Assets'])
plt.xlabel('Month')
plt.ylabel('Total Assets')
plt.title('Total Assets vs Month')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3-2896399730.py in <cell line: 0>()
#     103
#     104 # Get user inputs
# --> 105 annual_active_income = float(input("Enter your annual active income: "))
#     106 current_equities = float(input("Enter your current equities: "))
#     107 cash = float(input("Enter your current cash: "))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


def calculate_monthly_expenses(home_value, option):
    """Calculates monthly expenses based on home value or rent."""
    if option == 1:  # Homeownership
        utilities = 0.01 * home_value / 12
        maintenance = 0.01 * home_value / 12
        property_tax = 0.014 * home_value / 12
        insurance = 0.004 * home_value / 12
        return utilities + maintenance + property_tax + insurance
    else:  # Renting
        return 0.1 * home_value

def calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years):
    """Calculates the monthly mortgage payment."""
    monthly_interest_rate = annual_interest_rate / 12 / 100
    loan_term_months = loan_term_years * 12
    return (loan_amount * monthly_interest_rate * (1 + monthly_interest_rate) ** loan_term_months) / (
        (1 + monthly_interest_rate) ** loan_term_months - 1)

def calculate_savings(income, expenses, credit_card, insurance, pension, misc, mortgage):
    """Calculates monthly savings based on income and expenses."""
    return income - (expenses + credit_card + insurance + pension + misc + mortgage)

def calculate_investment_return(equities, market_return, tax_rate):
    """Calculates the monthly investment return after taxes."""
    return (equities * market_return) * (1 - tax_rate)

def simulate_financial_life(annual_active_income, current_equities, cash, credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value,  # Added home_value as argument
                             loan_amount, annual_interest_rate, loan_term_years, savings_percentage, cash_percentage,
                             equity_percentage, retirement_year, prepayment_percentage): # Changed to prepayment_percentage
    """Simulates financial life based on user inputs and calculates financial metrics."""

    data = {}
    data["annual_active_income"] = annual_active_income
    data["current_equities"] = current_equities
    data["cash"] = cash
    data["credit_card"] = credit_card
    data["insurance"] = insurance
    data["pension"] = pension
    data["misc"] = misc
    data["tax_on_active_income"] = 0.3  # Replace with actual tax rate
    data["avg_ann_income_raise"] = 0  # Replace with actual average annual income raise
    data["avg_ann_inflation"] = 0.03  # Replace with actual average annual inflation
    data["tax_on_investment_gains"] = 0  # Replace with actual tax rate
    data["avg_monthly_market_returns"] = 0.007  # Replace with actual average monthly market returns
    data["avg_monthly_market_volatility"] = 0.02  # Replace with actual average monthly market volatility
    data["retirement_year"] = retirement_year
    data["maturity"] = loan_term_years
    data["savings_percentage"] = savings_percentage / 100

    df = pd.DataFrame(columns=["Month", "Assets", "Outflows", "Inflows", "Income", "Investment Return",
                               "Rent", "CreditCard", "Insurance", "Pension", "Misc", "Mortgage", "Savings", "Equity", "Cash"])

    monthly_expenses = calculate_monthly_expenses(home_value, rent_or_mortgage) # Now home_value is available
    monthly_mortgage_payment = calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years)

    assets = current_equities + cash
    for month in range(1, 12 * retirement_year + 1):
        income = data["annual_active_income"] / 12

        investment_return = calculate_investment_return(current_equities, data["avg_monthly_market_returns"],
                                                        data["tax_on_investment_gains"])

        if rent_or_mortgage == 1:
          rent = 0
          mortgage = monthly_mortgage_payment
        else:
          rent = monthly_expenses
          mortgage = 0

        savings = calculate_savings(income, monthly_expenses, credit_card, insurance, pension, misc, mortgage)

        monthly_prepayment = prepayment_percentage/100 * savings # Calculate prepayment amount from percentage

        outflows = monthly_expenses + credit_card + insurance + pension + misc + mortgage + monthly_prepayment # Include prepayment in outflows
        inflows = income + investment_return

        assets = assets + inflows - outflows
        current_equities = current_equities + equity_percentage/100 * savings + investment_return
        cash = cash + cash_percentage/100 * savings - monthly_prepayment # Deduct prepayment from cash

        new_row = pd.DataFrame({"Month": [month], "Assets": [assets], "Outflows": [outflows], "Inflows": [inflows],
                                "Income": [income], "Investment Return": [investment_return], "Rent": [rent],
                                "CreditCard": [credit_card], "Insurance": [insurance], "Pension": [pension],
                                "Misc": [misc], "Mortgage": [mortgage], "Savings": [savings],
                                "Equity": [current_equities], "Cash": [cash]})
        df = pd.concat([df, new_row], ignore_index=True)

        # Apply annual income raise and inflation adjustments
        data["annual_active_income"] *= (1 + data["avg_ann_income_raise"])
        monthly_expenses *= (1 + data["avg_ann_inflation"])
        credit_card *= (1 + data["avg_ann_inflation"])
        insurance *= (1 + data["avg_ann_inflation"])
        pension *= (1 + data["avg_ann_inflation"])
        misc *= (1 + data["avg_ann_inflation"])

    return df


# Get user inputs
annual_active_income = float(input("Enter your annual active income: "))
current_equities = float(input("Enter your current equities: "))
cash = float(input("Enter your current cash: "))
credit_card = float(input("Enter your monthly credit card expenses: "))
insurance = float(input("Enter your monthly insurance expenses: "))
pension = float(input("Enter your monthly pension contributions: "))
misc = float(input("Enter your monthly miscellaneous expenses: "))
rent_or_mortgage = int(input("Enter 1 if you have a mortgage, 2 if you rent: "))
home_value = float(input("Enter your home value or monthly rent: "))
loan_amount = float(input("Enter your loan amount (0 if renting): "))
annual_interest_rate = float(input("Enter your annual interest rate (0 if renting): "))
loan_term_years = int(input("Enter your loan term in years (0 if renting): "))
savings_percentage = float(input("Enter your savings percentage: "))
cash_percentage = float(input("Enter the percentage of savings to be kept in cash: "))
equity_percentage = float(input("Enter the percentage of savings to be invested in equities: "))
retirement_year = int(input("Enter your desired retirement year: "))
prepayment_percentage = float(input("Enter the percentage of savings you want to use for prepayment: ")) # Get prepayment percentage

# Example usage with user inputs
df = simulate_financial_life(annual_active_income, current_equities, cash,
                             credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value, loan_amount,
                             annual_interest_rate, loan_term_years, savings_percentage,
                             cash_percentage, equity_percentage, retirement_year, prepayment_percentage)

print(df)

# Create the graph
plt.plot(df['Month'], df['Assets'])
plt.xlabel('Month')
plt.ylabel('Total Assets')
plt.title('Total Assets vs Month')
plt.show()
# Out:
# Enter your annual active income: 100000
# Enter your current equities: 100000
# Enter your current cash: 100000
# Enter your monthly credit card expenses: 100
# Enter your monthly insurance expenses: 100
# Enter your monthly pension contributions: 0
# Enter your monthly miscellaneous expenses: 100
# Enter 1 if you have a mortgage, 2 if you rent: 1
# Enter your home value or monthly rent: 500000
# Enter your loan amount (0 if renting): 480000
# Enter your annual interest rate (0 if renting): 6.5
# Enter your loan term in years (0 if renting): 30
# Enter your savings percentage: 30
# Enter the percentage of savings to be kept in cash: 20
# Enter the percentage of savings to be invested in equities: 20
# Enter your desired retirement year: 15
# Enter the percentage of savings you want to use for prepayment: 30
# ...

# %%
# prompt: make the graph above interactive

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

def calculate_monthly_expenses(home_value, option):
    """Calculates monthly expenses based on home value or rent."""
    if option == 1:  # Homeownership
        utilities = 0.01 * home_value / 12
        maintenance = 0.01 * home_value / 12
        property_tax = 0.014 * home_value / 12
        insurance = 0.004 * home_value / 12
        return utilities + maintenance + property_tax + insurance
    else:  # Renting
        return 0.1 * home_value

def calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years):
    """Calculates the monthly mortgage payment."""
    monthly_interest_rate = annual_interest_rate / 12 / 100
    loan_term_months = loan_term_years * 12
    return (loan_amount * monthly_interest_rate * (1 + monthly_interest_rate) ** loan_term_months) / (
        (1 + monthly_interest_rate) ** loan_term_months - 1)

def calculate_savings(income, expenses, credit_card, insurance, pension, misc, mortgage):
    """Calculates monthly savings based on income and expenses."""
    return income - (expenses + credit_card + insurance + pension + misc + mortgage)

def calculate_investment_return(equities, market_return, tax_rate):
    """Calculates the monthly investment return after taxes."""
    return (equities * market_return) * (1 - tax_rate)

def simulate_financial_life(annual_active_income, current_equities, cash, credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value,  # Added home_value as argument
                             loan_amount, annual_interest_rate, loan_term_years, savings_percentage, cash_percentage,
                             equity_percentage, retirement_year, prepayment_percentage): # Changed to prepayment_percentage
    """Simulates financial life based on user inputs and calculates financial metrics."""

    data = {}
    data["annual_active_income"] = annual_active_income
    data["current_equities"] = current_equities
    data["cash"] = cash
    data["credit_card"] = credit_card
    data["insurance"] = insurance
    data["pension"] = pension
    data["misc"] = misc
    data["tax_on_active_income"] = 0.3  # Replace with actual tax rate
    data["avg_ann_income_raise"] = 0  # Replace with actual average annual income raise
    data["avg_ann_inflation"] = 0.03  # Replace with actual average annual inflation
    data["tax_on_investment_gains"] = 0  # Replace with actual tax rate
    data["avg_monthly_market_returns"] = 0.007  # Replace with actual average monthly market returns
    data["avg_monthly_market_volatility"] = 0.02  # Replace with actual average monthly market volatility
    data["retirement_year"] = retirement_year
    data["maturity"] = loan_term_years
    data["savings_percentage"] = savings_percentage / 100

    df = pd.DataFrame(columns=["Month", "Assets", "Outflows", "Inflows", "Income", "Investment Return",
                               "Rent", "CreditCard", "Insurance", "Pension", "Misc", "Mortgage", "Savings", "Equity", "Cash"])

    monthly_expenses = calculate_monthly_expenses(home_value, rent_or_mortgage) # Now home_value is available
    monthly_mortgage_payment = calculate_mortgage_payment(loan_amount, annual_interest_rate, loan_term_years)

    assets = current_equities + cash
    for month in range(1, 12 * retirement_year + 1):
        income = data["annual_active_income"] / 12

        investment_return = calculate_investment_return(current_equities, data["avg_monthly_market_returns"],
                                                        data["tax_on_investment_gains"])

        if rent_or_mortgage == 1:
          rent = 0
          mortgage = monthly_mortgage_payment
        else:
          rent = monthly_expenses
          mortgage = 0

        savings = calculate_savings(income, monthly_expenses, credit_card, insurance, pension, misc, mortgage)

        monthly_prepayment = prepayment_percentage/100 * savings # Calculate prepayment amount from percentage

        outflows = monthly_expenses + credit_card + insurance + pension + misc + mortgage + monthly_prepayment # Include prepayment in outflows
        inflows = income + investment_return

        assets = assets + inflows - outflows
        current_equities = current_equities + equity_percentage/100 * savings + investment_return
        cash = cash + cash_percentage/100 * savings - monthly_prepayment # Deduct prepayment from cash

        new_row = pd.DataFrame({"Month": [month], "Assets": [assets], "Outflows": [outflows], "Inflows": [inflows],
                                "Income": [income], "Investment Return": [investment_return], "Rent": [rent],
                                "CreditCard": [credit_card], "Insurance": [insurance], "Pension": [pension],
                                "Misc": [misc], "Mortgage": [mortgage], "Savings": [savings],
                                "Equity": [current_equities], "Cash": [cash]})
        df = pd.concat([df, new_row], ignore_index=True)

        # Apply annual income raise and inflation adjustments
        data["annual_active_income"] *= (1 + data["avg_ann_income_raise"])
        monthly_expenses *= (1 + data["avg_ann_inflation"])
        credit_card *= (1 + data["avg_ann_inflation"])
        insurance *= (1 + data["avg_ann_inflation"])
        pension *= (1 + data["avg_ann_inflation"])
        misc *= (1 + data["avg_ann_inflation"])

    return df

def plot_interactive_graph(df):
  @interact(column=['Assets', 'Outflows', 'Inflows', 'Income', 'Investment Return', 'Rent',
                    'CreditCard', 'Insurance', 'Pension', 'Misc', 'Mortgage', 'Savings', 'Equity', 'Cash'])
  def update(column = 'Assets'):
    plt.plot(df['Month'], df[column])
    plt.xlabel('Month')
    plt.ylabel(column)
    plt.title(f'{column} vs Month')
    plt.show()

# Get user inputs
annual_active_income = float(input("Enter your annual active income: "))
current_equities = float(input("Enter your current equities: "))
cash = float(input("Enter your current cash: "))
credit_card = float(input("Enter your monthly credit card expenses: "))
insurance = float(input("Enter your monthly insurance expenses: "))
pension = float(input("Enter your monthly pension contributions: "))
misc = float(input("Enter your monthly miscellaneous expenses: "))
rent_or_mortgage = int(input("Enter 1 if you have a mortgage, 2 if you rent: "))
home_value = float(input("Enter your home value or monthly rent: "))
loan_amount = float(input("Enter your loan amount (0 if renting): "))
annual_interest_rate = float(input("Enter your annual interest rate (0 if renting): "))
loan_term_years = int(input("Enter your loan term in years (0 if renting): "))
savings_percentage = float(input("Enter your savings percentage: "))
cash_percentage = float(input("Enter the percentage of savings to be kept in cash: "))
equity_percentage = float(input("Enter the percentage of savings to be invested in equities: "))
retirement_year = int(input("Enter your desired retirement year: "))
prepayment_percentage = float(input("Enter the percentage of savings you want to use for prepayment: ")) # Get prepayment percentage

# Example usage with user inputs
df = simulate_financial_life(annual_active_income, current_equities, cash,
                             credit_card, insurance, pension, misc,
                             rent_or_mortgage, home_value, loan_amount,
                             annual_interest_rate, loan_term_years, savings_percentage,
                             cash_percentage, equity_percentage, retirement_year, prepayment_percentage)

print(df)

plot_interactive_graph(df)
# Out:
# Enter your annual active income: 300000
# Enter your current equities: 400000
# Enter your current cash: 200000
# Enter your monthly credit card expenses: 1000
# Enter your monthly insurance expenses: 1000
# Enter your monthly pension contributions: 0
# Enter your monthly miscellaneous expenses: 1000
# Enter 1 if you have a mortgage, 2 if you rent: 1
# Enter your home value or monthly rent: 1500000
# Enter your loan amount (0 if renting): 1200000
# Enter your annual interest rate (0 if renting): 6.5
# Enter your loan term in years (0 if renting): 30
# Enter your savings percentage: 0
# Enter the percentage of savings to be kept in cash: 50
# Enter the percentage of savings to be invested in equities: 0
# Enter your desired retirement year: 5
# Enter the percentage of savings you want to use for prepayment: 50
#    Month         Assets      Outflows       Inflows   Income  \
# 0      1  607632.591859  20167.408141  27800.000000  25000.0
# ...
